# %%
import os
import sys
from pathlib import Path
from dotenv import load_dotenv, find_dotenv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('bmh')
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())

data_path = Path(os.environ.get('PROJECT_DATA'))
sys.path.append(os.environ.get('PROJECT_ROOT'))

# %%
files = os.listdir(data_path / 'raw_paper_data')

# %%
df = pd.read_excel(
            data_path / 'raw_paper_data' / files[1],
            sheet_name=2
            )
print(pd.ExcelFile(data_path / 'raw_paper_data' / files[1]).sheet_names)

df = df.drop(columns=['Unnamed: 9'])
df = df.dropna()

df
# Out:
# ['Contents', 'Global_EGS_potential_2015LCOE', 'Global_EGS_potential_2020LCOE', 'Global_EGS_potential_2025LCOE', 'Global_EGS_potential_2030LCOE', 'Global_EGS_potential_2035LCOE', 'Global_EGS_potential_2040LCOE', 'Global_EGS_potential_2045LCOE', 'Global_EGS_potential_2050LCOE']
#     Geothermal potential by country Available heat potential (TWh_th)  \
# 0                            Global                    3331905.695453
# 1                       Afghanistan                                 0
# 2                           Albania                                 0
# 3                           Algeria                      85089.236497
# 4                            Angola                                 0
# ..                              ...                               ...
# 337                         SE-Asia                                 0
# 338                           SAARC                                 0
# ...

# %%
df = pd.read_excel(
            data_path / 'raw_paper_data' / files[2],
            sheet_name=2
            )

#df = df.drop(columns=['Unnamed: 9'])

df
# Out:
#     Geothermal potential by country for the LCOE range of 10:5:>100 €/MWh  \
# 0                                               Global
# 1                                          Afghanistan
# 2                                              Albania
# 3                                              Algeria
# 4                                               Angola
# ..                                                 ...
# 344                                                NaN
# 345                                                NaN
# 346                                                NaN
# 347                                                NaN
# 348                                   Back to Contents
#
#     Heat potential for 10-15€/MWh LCOE (TWh_th)  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# ...

# %%
files
# Out:
# ['1-s2.0-S0306261920312551-mmc1.pdf',
#  '1-s2.0-S0306261920312551-mmc2.xlsx',
#  '1-s2.0-S0306261920312551-mmc3.xlsx',
#  '1-s2.0-S0306261920312551-mmc4.xlsx']

# %%
DATA_FILES = ['1-s2.0-S0306261920312551-mmc2.xlsx',
              '1-s2.0-S0306261920312551-mmc3.xlsx',
              '1-s2.0-S0306261920312551-mmc4.xlsx']
RAWDATA_PATH = data_path / 'raw_paper_data'


def get_geothermal_data(country):
    '''
    Obtains time series of capital and marginal cost, and available technical potential for passed country 
   
    Args:
        country(str): data is obtained for this country 
    '''
    
    country = country.capitalize()
    
    sheets = pd.ExcelFile(RAWDATA_PATH / DATA_FILES[0]).sheet_names
    
    data_years = [pd.Timestamp(year) for year in ['2015', '2020']] 
    
     
    
    
    
    
    print(country)

    

    

    
    
get_geothermal_data('germany')
# Out:
# germany

# %%
print(3)
# Out:
# 3
